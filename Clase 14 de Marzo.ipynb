# %%
import sympy as sy
import numpy as np
import matplotlib.pyplot as plt

n=sy.symbols('n')
x=sy.symbols('x')
pi=3

for n in range (1,100000000):
    t=3+4*(((-1)**(n+1))/((2*n)*(2*(n+1))*(2*(n+2))))
    pi+=t
display (pi)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-d99fbd150f23> in <module>
#       8
#       9 for n in range (1,100000000):
# ---> 10     t=3+4*(((-1)**(n+1))/((2*n)*(2*(n+1))*(2*(n+2))))
#      11     pi+=t
#      12 display (pi)
#
# KeyboardInterrupt:

# %%
import mpmath as mp

mp.mp.dps=1000
pi=3
#nilakantha
for n in range (1,1000000):
    t=4*(((mp.mpf(-1)**(n+1)))/((2*n)*(2*(n+1))*(2*(n+2))))
    pi+=t
display (pi)
# Out:
# mpf('3....')

# %%
for n in range(1000):
    pi=1/16**n((4/(8*(n+1))()()())

# %%
import mpmath as mp
import sympy as sy

x=sy.symbols('x')

mp.mp.dps=2000
def f(x):
    return 1/(mp.sqrt(1-x**2))
#p1 = sy.integrate(1/(sy.sqrt(1-(x**2))), (x, -1, 1))
p1=mp.quad(f,[-1,1])

print (p1)

str(p1.find('999999'))
# Out:
# 3....
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-00a8240aabae> in <module>
#      12 print (p1)
#      13
# ---> 14 str(p1.find('999999'))
#
# AttributeError: 'mpf' object has no attribute 'find'
